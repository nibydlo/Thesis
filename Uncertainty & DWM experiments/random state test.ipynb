# %%
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('/Users/dmitry/Desktop/Thesis/Libs')

# %%
from plots import plot_conf_int, plot_single

# %%
import pickle

file = open('mnist_init_size_stat.pkl', 'rb')
mnist_entropy_stat = pickle.load(file)['entropy'][2000]

# %%
it = 0
for attempt in mnist_entropy_stat:
    plot_single(attempt, it)
    it += 1
plt.rcParams["figure.figsize"] = (40,4.8)
plt.show()

# %%
plot_conf_int(mnist_entropy_stat, "entropy")
plt.rcParams["figure.figsize"] = (10,4.8)
plt.show()
