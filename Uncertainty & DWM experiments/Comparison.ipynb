# %%
import pickle
import matplotlib.pyplot as plt

# %%
file = open('mnist_init_size_stat.pkl', 'rb')
mnist_entropy = pickle.load(file)['entropy'][2000]

# %%
file = open('mnist_sbc_stat.pkl', 'rb')
mnist_sbc = pickle.load(file)

# %%
file = open('mnist_sud_stat.pkl', 'rb')
mnist_sud = pickle.load(file)

# %%
file = open('mnist_sbc_sud_stat.pkl', 'rb')
mnist_sbc_sud = pickle.load(file)

# %%
import sys
sys.path.append('/Users/dmitry/Desktop/Thesis/Libs')

# %%
from plots import plot_conf_int

plot_conf_int(mnist_entropy, "uncertainty only")
plot_conf_int(mnist_sbc, "SBC")
plot_conf_int(mnist_sud, "SUD")
plot_conf_int(mnist_sbc_sud, "SBC + SUD")
plt.xlabel('labeled set size')
plt.ylabel('accuracy')
plt.legend(loc='lower right')
plt.rcParams["figure.figsize"] = (20,5)
plt.show()
